# %% [markdown]
# <a href="https://colab.research.google.com/github/Kangmin22/mini-t-project-type-2/blob/main/Mini_T.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python -m src.hpo.optimize
# Out:
# Phase 2 HPO Started on A100: Searching for optimal geometric parameters with AMP...
# 2025-07-04 09:57:00,170	INFO worker.py:1621 -- Started a local Ray instance.
# 2025-07-04 09:57:01,641	INFO tune.py:226 -- Initializing Ray automatically. For cluster usage or custom Ray initialization, call `ray.init(...)` before `Tuner(...)`.
# 2025-07-04 09:57:01,643	INFO tune.py:666 -- [output] This will use the new output engine with verbosity 1. To disable the new output and use the legacy output engine, set the environment variable RAY_AIR_NEW_OUTPUT=0. For more information, please see https://github.com/ray-project/ray/issues/36949
# [I 2025-07-04 09:57:01,658] A new study created in memory with name: optuna
# ╭───────────────────────────────────────────────────────────╮
# │ Configuration for experiment     Geometric_PID_HPO_A100   │
# ├───────────────────────────────────────────────────────────┤
# │ Search algorithm                 SearchGenerator          │
# ...
